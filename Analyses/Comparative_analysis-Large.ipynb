# %% [markdown]
# # Comparative analysis of ensemble simulations (large populations)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style("whitegrid")

#matplotlib preamble, taken from http://blog.juliusschulz.de/blog/ultimate-ipython-notebook
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('pdf', 'png')
plt.rcParams['savefig.dpi'] = 75

plt.rcParams['figure.autolayout'] = False
plt.rcParams['figure.figsize'] = 14, 7
plt.rcParams['axes.labelsize'] = 18
plt.rcParams['axes.titlesize'] = 20
plt.rcParams['font.size'] = 16
plt.rcParams['lines.linewidth'] = 2.0
plt.rcParams['lines.markersize'] = 8
plt.rcParams['legend.fontsize'] = 14

# %% [markdown]
# ## Load data

# %%
neutral = pd.read_csv('./Analysis-Data/Large-neutral-1000_sim-Analyzed_data.csv', index_col=0)
selection_0p004 = pd.read_csv('./Analysis-Data/Large-selection_0p004-1000_sim-Analyzed_data.csv', index_col=0)
selection_0p01 = pd.read_csv('./Analysis-Data/Large-selection_0p01-1000_sim-Analyzed_data.csv', index_col=0)
selection_0p05 = pd.read_csv('./Analysis-Data/Large-selection_0p05-1000_sim-Analyzed_data.csv', index_col=0)
selection_0p1 = pd.read_csv('./Analysis-Data/Large-selection_0p1-1000_sim-Analyzed_data.csv', index_col=0)
selection_0p15 = pd.read_csv('./Analysis-Data/Large-selection_0p15-1000_sim-Analyzed_data.csv', index_col=0)
selection_0p2 = pd.read_csv('./Analysis-Data/Large-selection_0p2-1000_sim-Analyzed_data.csv', index_col=0)
selection_0p3 = pd.read_csv('./Analysis-Data/Large-selection_0p3-1000_sim-Analyzed_data.csv', index_col=0)
selection_1p5 = pd.read_csv('./Analysis-Data/Large-selection_1p5-1000_sim-Analyzed_data.csv', index_col=0)
selection_3 = pd.read_csv('./Analysis-Data/Large-selection_3-1000_sim-Analyzed_data.csv', index_col=0)

# %%
# different selection factors that were used for populations in order
selection_values = [0, 0.004, 0.01, 0.05, 0.1, 0.15, 0.2, 0.3, 1.5, 3]

# %%
def ecdf(data):
    """Compute ECDF for a one-dimensional array of measurements."""

    # Number of data points: n
    n = len(data)

    # x-data for the ECDF: x
    x = np.sort(data)

    # y-data for the ECDF: y
    y = np.arange(1, n+1) / n

    return x, y

# %% [markdown]
# ## Maximum allele frequencies

# %%
neutral_MaxAFs = neutral["neutral_MaxAFs"].values
selection_0p004_MaxAFs = selection_0p004["selection_0p004_MaxAFs"].values
selection_0p01_MaxAFs = selection_0p01["selection_0p01_MaxAFs"].values
selection_0p05_MaxAFs = selection_0p05["selection_0p05_MaxAFs"].values
selection_0p1_MaxAFs = selection_0p1["selection_0p1_MaxAFs"].values
selection_0p15_MaxAFs = selection_0p15["selection_0p15_MaxAFs"].values
selection_0p2_MaxAFs = selection_0p2["selection_0p2_MaxAFs"].values
selection_0p3_MaxAFs = selection_0p3["selection_0p3_MaxAFs"].values
selection_1p5_MaxAFs = selection_1p5["selection_1p5_MaxAFs"].values
selection_3_MaxAFs = selection_3["selection_3_MaxAFs"].values

pop_MaxAFs = [neutral_MaxAFs, selection_0p004_MaxAFs, selection_0p01_MaxAFs, 
              selection_0p05_MaxAFs, selection_0p1_MaxAFs, selection_0p15_MaxAFs,
              selection_0p2_MaxAFs, selection_0p3_MaxAFs, selection_1p5_MaxAFs, selection_3_MaxAFs]

# %%
total_maxAFs = pd.DataFrame({'sel_factor': 0, 'max_AF': neutral_MaxAFs})

for sel, maxAFs in zip(selection_values[1:], pop_MaxAFs[1:]):
    df = pd.DataFrame({'sel_factor': sel, 'max_AF': maxAFs})
    total_maxAFs = pd.concat([total_maxAFs, df])

# %%
plt.figure()
for sel, maxAF in zip(selection_values, pop_MaxAFs):
    sns.distplot(maxAF, bins=100, kde=False, norm_hist=True, label="Selection = %s" %(sel));

plt.xlabel('Max allele frequency');
plt.ylabel('Normalized count');
plt.legend(frameon=True, fancybox=True, shadow=True);
plt.legend(loc='upper right', bbox_to_anchor=(1.22,1), frameon=True, fancybox=True, shadow=True);
plt.margins(0.02);
plt.show()

# %%
plt.figure();
for sel, maxAF in zip(selection_values, pop_MaxAFs):
    x, y = ecdf(maxAF)
    plt.plot(x, y, marker='.', linestyle='none', alpha=0.5, label='Selection = %s' %sel);

plt.xlabel('Max allele frequency');
plt.ylabel('CDF');
plt.legend(loc='upper right', bbox_to_anchor=(1.22,1), frameon=True, fancybox=True, shadow=True, borderaxespad=0.);
plt.margins(0.02);
plt.savefig('./Figures/Comparative_analysis-Large-Figures/COMBO-Max_AFs-CDF.png', bbox_inches='tight')
plt.show()

# %%
sns.boxplot(x='sel_factor', y='max_AF', data=total_maxAFs);
plt.xlabel('Selection factor');
plt.ylabel('Max allele frequency');
plt.savefig('./Figures/Comparative_analysis-Large-Figures/COMBO-Max_AFs-Boxplot.png', bbox_inches='tight')
plt.show()

# %%
med_max_afs = []
for max_af in pop_MaxAFs:
    med_max_afs.append(np.median(max_af))

# %%
plt.plot(selection_values, med_max_afs, marker='o', linestyle='--', color='k');
plt.xlabel("Selection factor");
plt.ylabel("Median max allele frequency");
plt.xscale('log');
plt.savefig('./Figures/Comparative_analysis-Large-Figures/COMBO-Max_AFs-Median_scaled.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Heterogeneity

# %%
neutral_H = neutral["neutral_H"].values
selection_0p004_H = selection_0p004["selection_0p004_H"].values
selection_0p01_H = selection_0p01["selection_0p01_H"].values
selection_0p05_H = selection_0p05["selection_0p05_H"].values
selection_0p1_H = selection_0p1["selection_0p1_H"].values
selection_0p15_H = selection_0p15["selection_0p15_H"].values
selection_0p2_H = selection_0p2["selection_0p2_H"].values
selection_0p3_H = selection_0p3["selection_0p3_H"].values
selection_1p5_H = selection_1p5["selection_1p5_H"].values
selection_3_H = selection_3["selection_3_H"].values

pop_H = [neutral_H, selection_0p004_H, selection_0p01_H, selection_0p05_H, selection_0p1_H,
         selection_0p15_H, selection_0p2_H, selection_0p3_H, selection_1p5_H, selection_3_H]

# %%
total_H = pd.DataFrame({'sel_factor': 0, 'heterogeneity': neutral_H})

for sel, H in zip(selection_values[1:], pop_H[1:]):
    df = pd.DataFrame({'sel_factor': sel, 'heterogeneity': H})
    total_H = pd.concat([total_H, df])

# %%
plt.figure()
for sel, H in zip(selection_values, pop_H):
    sns.distplot(H, bins=100, kde=False, norm_hist=True, label="Selection = %s" %(sel));

plt.xlabel('Heterogeneity');
plt.ylabel('Normalized count');
plt.margins(0.02);
plt.legend(frameon=True, fancybox=True, shadow=True);
plt.legend(loc='upper right', bbox_to_anchor=(1.22,1), frameon=True, fancybox=True, shadow=True);
plt.show()

# %%
plt.figure()
for sel, H in zip(selection_values, pop_H):
    x, y = ecdf(H)
    plt.plot(x, y, marker='.', linestyle='none', alpha=0.5, label='Selection = %s' %sel);

plt.xlabel('Heterogeneity');
plt.ylabel('CDF');
plt.legend(loc='upper right', bbox_to_anchor=(1.22,1), frameon=True, fancybox=True, shadow=True);
x, y = plt.xlim(-0.01, 1.01)
#plt.margins(0.02);
plt.savefig('./Figures/Comparative_analysis-Large-Figures/COMBO-Heterogeneity-CDF.png', bbox_inches='tight')
plt.show()

# %%
sns.boxplot(x='sel_factor', y='heterogeneity', data=total_H);
plt.xlabel('Selection factor');
plt.ylabel('Heterogeneity');
plt.savefig('./Figures/Comparative_analysis-Large-Figures/COMBO-Heterogeneity-Boxplot.png', bbox_inches='tight')
plt.show()

# %%
med_H = []
for H in pop_H:
    med_H.append(np.median(H))

# %%
plt.plot(selection_values, med_H, marker='o', linestyle='--', color='k');
plt.xlabel("Selection factor");
plt.ylabel("Median Heterogeneity");
plt.xscale('log');
plt.savefig('./Figures/Comparative_analysis-Large-Figures/COMBO-Heterogeneity-Median_scaled.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Mutational burden (number of mutations distribution)

# %%
neutral_mut_distr = pd.read_csv('./Analysis-Data/Large-1000_sim-neutral_mut_distr.csv', index_col=0)
neutral_mut_distr.columns = neutral_mut_distr.columns.astype(int)

selection_0p004_mut_distr = pd.read_csv('./Analysis-Data/Large-1000_sim-selection_0p004_mut_distr.csv', index_col=0)
selection_0p004_mut_distr.columns = selection_0p004_mut_distr.columns.astype(int)

selection_0p01_mut_distr = pd.read_csv('./Analysis-Data/Large-1000_sim-selection_0p01_mut_distr.csv', index_col=0)
selection_0p01_mut_distr.columns = selection_0p01_mut_distr.columns.astype(int)

selection_0p05_mut_distr = pd.read_csv('./Analysis-Data/Large-1000_sim-selection_0p05_mut_distr.csv', index_col=0)
selection_0p05_mut_distr.columns = selection_0p05_mut_distr.columns.astype(int)

selection_0p1_mut_distr = pd.read_csv('./Analysis-Data/Large-1000_sim-selection_0p1_mut_distr.csv', index_col=0)
selection_0p1_mut_distr.columns = selection_0p1_mut_distr.columns.astype(int)

selection_0p15_mut_distr = pd.read_csv('./Analysis-Data/Large-1000_sim-selection_0p15_mut_distr.csv', index_col=0)
selection_0p15_mut_distr.columns = selection_0p15_mut_distr.columns.astype(int)

selection_0p2_mut_distr = pd.read_csv('./Analysis-Data/Large-1000_sim-selection_0p2_mut_distr.csv', index_col=0)
selection_0p2_mut_distr.columns = selection_0p2_mut_distr.columns.astype(int)

selection_0p3_mut_distr = pd.read_csv('./Analysis-Data/Large-1000_sim-selection_0p3_mut_distr.csv', index_col=0)
selection_0p3_mut_distr.columns = selection_0p3_mut_distr.columns.astype(int)

selection_1p5_mut_distr = pd.read_csv('./Analysis-Data/Large-1000_sim-selection_1p5_mut_distr.csv', index_col=0)
selection_1p5_mut_distr.columns = selection_1p5_mut_distr.columns.astype(int)

selection_3_mut_distr = pd.read_csv('./Analysis-Data/Large-1000_sim-selection_3_mut_distr.csv', index_col=0)
selection_3_mut_distr.columns = selection_3_mut_distr.columns.astype(int)

nmd_list = [neutral_mut_distr, selection_0p004_mut_distr, selection_0p01_mut_distr, selection_0p05_mut_distr,
            selection_0p1_mut_distr, selection_0p15_mut_distr, selection_0p2_mut_distr, selection_0p3_mut_distr, 
            selection_1p5_mut_distr, selection_3_mut_distr]

# %%
avg_NMDs = []
std_NMDs = []

for nmd in nmd_list:
    avg_nmd = nmd.mean()
    std_nmd = nmd.std()
    avg_NMDs.append(avg_nmd)
    std_NMDs.append(std_nmd)

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('../'))
if module_path not in sys.path:
    sys.path.append(module_path)
from ThesisScripts.Analyses import avg_num_mutations

# %%
plt.figure();
offset = -0.225
for sel, avg_nmd in zip(selection_values, avg_NMDs):
    avg_num_mut = avg_num_mutations(avg_nmd)
    
    plt.plot(avg_nmd.index+offset, avg_nmd.values, linestyle='--', alpha=1);
    plt.bar(left=avg_nmd.index+offset, height=avg_nmd.values, width=0.05, alpha=0.3, 
           label="Selection = %s, mean = %s" %(sel, round(avg_num_mut, 3)));
    offset += 0.05
    
plt.xlabel("Number of mutations");
plt.ylabel("Cell count");
plt.yscale('log');
#plt.xticks();
plt.margins(0.02);
plt.legend(loc='upper right', bbox_to_anchor=(1.35,1), frameon=True, fancybox=True, shadow=True);
plt.savefig('./Figures/Comparative_analysis-Large-Figures/COMBO-Num_mut.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Total number of mutations

# %%
neutral_total_m = neutral["neutral_total_m"].values
selection_0p004_total_m = selection_0p004["selection_0p004_total_m"].values
selection_0p01_total_m = selection_0p01["selection_0p01_total_m"].values
selection_0p05_total_m = selection_0p05["selection_0p05_total_m"].values
selection_0p1_total_m = selection_0p1["selection_0p1_total_m"].values
selection_0p15_total_m = selection_0p15["selection_0p15_total_m"].values
selection_0p2_total_m = selection_0p2["selection_0p2_total_m"].values
selection_0p3_total_m = selection_0p3["selection_0p3_total_m"].values
selection_1p5_total_m = selection_1p5["selection_1p5_total_m"].values
selection_3_total_m = selection_3["selection_3_total_m"].values

total_Ms = [neutral_total_m, selection_0p004_total_m, selection_0p01_total_m, selection_0p05_total_m,
            selection_0p1_total_m, selection_0p15_total_m, selection_0p2_total_m, selection_0p3_total_m, 
            selection_1p5_total_m, selection_3_total_m]

# %%
sns.boxplot(data=total_Ms);
plt.ylabel("Total number of mutations");
plt.xlabel("Selection factor");
plt.xticks(range(len(total_Ms)), selection_values);
plt.savefig('./Figures/Comparative_analysis-Large-Figures/COMBO-Total_M-Boxplot.png', bbox_inches='tight')
plt.show()

# %%
med_M = []
for M in total_Ms:
    med_M.append(np.median(M))

# %%
plt.plot(selection_values, med_M, marker='o', linestyle='--', color='k');
plt.xlabel("Selection factor");
plt.ylabel("Median Total mutations");
plt.xscale('log');
plt.savefig('./Figures/Comparative_analysis-Large-Figures/COMBO-Total_M-Median_scaled.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Errors in reconstruction of mutational timeline

# %%
neutral_rec_errors = neutral["neutral_rec_errors"].values
selection_0p004_rec_errors = selection_0p004["selection_0p004_rec_errors"].values
selection_0p01_rec_errors = selection_0p01["selection_0p01_rec_errors"].values
selection_0p05_rec_errors = selection_0p05["selection_0p05_rec_errors"].values
selection_0p1_rec_errors = selection_0p1["selection_0p1_rec_errors"].values
selection_0p15_rec_errors = selection_0p15["selection_0p15_rec_errors"].values
selection_0p2_rec_errors = selection_0p2["selection_0p2_rec_errors"].values
selection_0p3_rec_errors = selection_0p3["selection_0p3_rec_errors"].values
selection_1p5_rec_errors = selection_1p5["selection_1p5_rec_errors"].values
selection_3_rec_errors = selection_3["selection_3_rec_errors"].values

total_rec_errors = [neutral_rec_errors, selection_0p004_rec_errors, selection_0p01_rec_errors, 
            selection_0p05_rec_errors, selection_0p1_rec_errors, selection_0p15_rec_errors,
            selection_0p2_rec_errors, selection_0p3_rec_errors, selection_1p5_rec_errors, 
            selection_3_rec_errors]

# %%
sns.boxplot(data=total_rec_errors);
plt.ylabel("MAD reconstruction errors");
plt.xticks(range(len(total_rec_errors)), selection_values);
plt.xlabel("Selection factor");
plt.margins(0.02);
plt.savefig('./Figures/Comparative_analysis-Large-Figures/COMBO-Rec_errors-Boxplot.png', bbox_inches='tight')
plt.show()

# %%
med_rec_errors = []
for rec_errors in total_rec_errors:
    med_rec_errors.append(np.median(rec_errors))

# %%
plt.plot(selection_values, med_rec_errors, marker='o', linestyle='--', color='k');
plt.xlabel("Selection factor");
plt.ylabel("Median Reconstruction errors");
plt.xscale('log');
plt.savefig('./Figures/Comparative_analysis-Large-Figures/COMBO-Rec_errors-Median_scaled.png', bbox_inches='tight')
plt.show()
