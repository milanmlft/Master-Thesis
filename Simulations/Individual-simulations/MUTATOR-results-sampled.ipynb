# %% [markdown]
# # Large Population: Neutral *vs* Selection
#
# The parameters are summarized in the table below:
#
# Parameter  | Neutral | Selection  |
# -----------|---------|------------|
# Final size | $10^8$  |   $10^8$   |
# q (start)  |$10^{-3}$| $10^{-3}$  |
# q-factor   | **3**  |   **3**    |
# P(death)   | $0.3$   |   $0.3$    |
# Selection  | 0   |  0.3   |

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from ThesisScripts.MyModel import *
from ThesisScripts.Analyses import *
from ThesisScripts.Visualizations import *
from ThesisScripts.PhyloTree import *

from IPython.display import Image

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style("whitegrid")

#matplotlib preamble, taken from http://blog.juliusschulz.de/blog/ultimate-ipython-notebook
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('pdf', 'png')
plt.rcParams['savefig.dpi'] = 75

plt.rcParams['figure.autolayout'] = False
plt.rcParams['figure.figsize'] = 14, 7
plt.rcParams['axes.labelsize'] = 18
plt.rcParams['axes.titlesize'] = 20
plt.rcParams['font.size'] = 16
plt.rcParams['lines.linewidth'] = 2.0
plt.rcParams['lines.markersize'] = 8
plt.rcParams['legend.fontsize'] = 14

# %%
# %ls Figures/
# Out:
# Large-HIGH_DEATH-Neutral_vs_Selection-SAMPLED/
# Large-HIGH_MUTRATE-Neutral_vs_Selection-SAMPLED/
# Large-MUTATOR-Neutral_vs_Selection-SAMPLED/
# Large-Neutral_vs_Selection-SAMPLED/

# %% [markdown]
# # Simulations

# %% [markdown]
# ## Neutral

# %%
# %%time
# set seed to get same result for each test simulation
np.random.seed(123)

# Test cell
l = 10**8      # size limit
q = 10**(-3)   # mutation rate
qfac = 3       # mutation-rate increasing factor (here: MUTATOR phenotype)
alpha = 0.3    # death rate
sel = 0        # selection factor
large_N = Population(l, q, mutfactor=qfac, death_frac=alpha, selection=sel)
large_N.simulate()
print("Total population size:", large_N.size)
print("Generations:", large_N.gen)
print()
print("Start clone size:", large_N.start_clone.size)
print("Number of subclones:", len(large_N.clones[1:]))
# Out:
# Total population size: 116402657
# Generations: 35
#
# Start clone size: 114973132
# Number of subclones: 169332
# CPU times: user 7.25 s, sys: 140 ms, total: 7.39 s
# Wall time: 7.49 s

# %% [markdown]
# ## In case of selection

# %%
# %%time
# set seed to get same result for each test simulation
np.random.seed(123)

# Test cell
l = 10**8      # size limit
q = 10**(-3)   # mutation rate
qfac = 3       # mutation-rate increasing factor (here: MUTATOR phenotype)
alpha = 0.3    # death rate
sel = 0.3      # selection factor
large_S = Population(l, q, mutfactor=qfac, death_frac=alpha, selection=sel)
large_S.simulate()
print("Total population size:", large_S.size)
print("Generations:", large_S.gen)
print()
print("Start clone size:", large_S.start_clone.size)
print("Number of subclones:", len(large_S.clones[1:]))
# Out:
# Subclones of clone A.1.8.0.0.1.0 have reached q = 1
# Subclones of clone A.1.101.0.0.0.0 have reached q = 1
# Subclones of clone A.1.63.0.0.0.0 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0 have reached q = 1
# Subclones of clone A.1.101.0.0.0.0 have reached q = 1
# Subclones of clone A.1.63.0.0.0.0 have reached q = 1
# Subclones of clone A.1.8.0.0.1.1 have reached q = 1
# Subclones of clone A.1.8.0.0.1.2 have reached q = 1
# Subclones of clone A.1.101.0.0.0.1 have reached q = 1
# Subclones of clone A.1.101.0.0.0.2 have reached q = 1
# Subclones of clone A.1.101.0.0.0.3 have reached q = 1
# Subclones of clone A.1.101.0.0.0.4 have reached q = 1
# Subclones of clone A.1.8.0.0.2.0 have reached q = 1
# Subclones of clone A.1.8.0.0.2.1 have reached q = 1
# Subclones of clone A.1.8.0.0.3.0 have reached q = 1
# Subclones of clone A.1.8.0.0.3.1 have reached q = 1
# Subclones of clone A.1.8.0.0.3.2 have reached q = 1
# Subclones of clone A.1.36.0.0.1.0 have reached q = 1
# Subclones of clone A.1.36.0.0.1.1 have reached q = 1
# Subclones of clone A.1.63.0.0.2.0 have reached q = 1
# Subclones of clone A.1.63.0.0.2.1 have reached q = 1
# Subclones of clone A.1.63.0.0.3.0 have reached q = 1
# Subclones of clone A.1.289.0.0.0.0 have reached q = 1
# Subclones of clone A.1.63.0.2.0.0 have reached q = 1
# Subclones of clone A.1.6.1.1.0.0 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0 have reached q = 1
# Subclones of clone A.1.63.0.0.0.0.0 have reached q = 1
# Subclones of clone A.1.63.0.0.0.0.1 have reached q = 1
# Subclones of clone A.1.63.0.0.0.0.2 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0 have reached q = 1
# Subclones of clone A.1.101.0.0.0.0 have reached q = 1
# Subclones of clone A.1.63.0.0.0.0 have reached q = 1
# Subclones of clone A.1.8.0.0.1.1 have reached q = 1
# Subclones of clone A.1.8.0.0.1.2 have reached q = 1
# Subclones of clone A.1.101.0.0.0.1 have reached q = 1
# Subclones of clone A.1.101.0.0.0.2 have reached q = 1
# Subclones of clone A.1.101.0.0.0.3 have reached q = 1
# Subclones of clone A.1.101.0.0.0.4 have reached q = 1
# Subclones of clone A.1.8.0.0.2.0 have reached q = 1
# Subclones of clone A.1.8.0.0.2.1 have reached q = 1
# Subclones of clone A.1.8.0.0.3.0 have reached q = 1
# Subclones of clone A.1.8.0.0.3.1 have reached q = 1
# Subclones of clone A.1.8.0.0.3.2 have reached q = 1
# Subclones of clone A.1.36.0.0.1.0 have reached q = 1
# Subclones of clone A.1.36.0.0.1.1 have reached q = 1
# Subclones of clone A.1.63.0.0.2.0 have reached q = 1
# Subclones of clone A.1.63.0.0.2.1 have reached q = 1
# Subclones of clone A.1.63.0.0.3.0 have reached q = 1
# Subclones of clone A.1.289.0.0.0.0 have reached q = 1
# Subclones of clone A.1.63.0.2.0.0 have reached q = 1
# Subclones of clone A.1.6.1.1.0.0 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0 have reached q = 1
# Subclones of clone A.1.63.0.0.0.0.0 have reached q = 1
# Subclones of clone A.1.63.0.0.0.0.1 have reached q = 1
# Subclones of clone A.1.63.0.0.0.0.2 have reached q = 1
# Subclones of clone A.1.21.0.0.0.0 have reached q = 1
# Subclones of clone A.1.21.0.0.0.1 have reached q = 1
# Subclones of clone A.1.21.0.0.0.2 have reached q = 1
# Subclones of clone A.1.8.0.0.0.0 have reached q = 1
# Subclones of clone A.1.8.0.0.1.3 have reached q = 1
# Subclones of clone A.1.8.0.0.1.4 have reached q = 1
# Subclones of clone A.1.8.0.0.1.5 have reached q = 1
# Subclones of clone A.1.101.0.0.0.5 have reached q = 1
# Subclones of clone A.1.42.1.0.0.0 have reached q = 1
# Subclones of clone A.1.8.0.0.2.2 have reached q = 1
# Subclones of clone A.1.8.0.0.3.3 have reached q = 1
# Subclones of clone A.1.36.0.0.1.2 have reached q = 1
# Subclones of clone A.1.36.0.0.1.3 have reached q = 1
# Subclones of clone A.1.36.0.0.1.4 have reached q = 1
# Subclones of clone A.1.36.0.0.1.5 have reached q = 1
# Subclones of clone A.1.36.0.0.1.6 have reached q = 1
# Subclones of clone A.1.36.0.0.2.0 have reached q = 1
# Subclones of clone A.1.36.0.0.2.1 have reached q = 1
# Subclones of clone A.1.36.0.0.4.0 have reached q = 1
# Subclones of clone A.1.36.0.0.4.1 have reached q = 1
# Subclones of clone A.1.36.0.0.4.2 have reached q = 1
# Subclones of clone A.1.21.0.1.0.0 have reached q = 1
# Subclones of clone A.1.63.0.0.2.2 have reached q = 1
# Subclones of clone A.1.63.0.0.2.3 have reached q = 1
# Subclones of clone A.1.63.0.0.2.4 have reached q = 1
# Subclones of clone A.1.63.0.0.2.5 have reached q = 1
# Subclones of clone A.1.4.3.0.1.0 have reached q = 1
# Subclones of clone A.1.89.1.1.0.0 have reached q = 1
# Subclones of clone A.1.89.1.1.0.1 have reached q = 1
# Subclones of clone A.1.89.1.1.0.2 have reached q = 1
# Subclones of clone A.1.141.0.0.0.0 have reached q = 1
# Subclones of clone A.1.289.0.0.0.1 have reached q = 1
# Subclones of clone A.1.289.0.0.0.2 have reached q = 1
# Subclones of clone A.1.63.0.2.0.1 have reached q = 1
# Subclones of clone A.1.2.0.0.0.0 have reached q = 1
# Subclones of clone A.1.6.1.0.0.0 have reached q = 1
# Subclones of clone A.1.6.1.0.0.1 have reached q = 1
# Subclones of clone A.1.6.1.0.0.2 have reached q = 1
# Subclones of clone A.1.6.1.1.0.1 have reached q = 1
# Subclones of clone A.1.6.1.1.0.2 have reached q = 1
# Subclones of clone A.1.6.1.1.0.3 have reached q = 1
# Subclones of clone A.1.6.1.1.0.4 have reached q = 1
# Subclones of clone A.1.101.0.0.0.0.0 have reached q = 1
# Subclones of clone A.1.101.0.0.0.0.1 have reached q = 1
# Subclones of clone A.1.21.0.0.1.0 have reached q = 1
# Subclones of clone A.1.8.0.0.4.0 have reached q = 1
# Subclones of clone A.1.8.0.0.6.0 have reached q = 1
# Subclones of clone A.1.101.0.0.3.0 have reached q = 1
# Subclones of clone A.1.36.0.0.11.0 have reached q = 1
# Subclones of clone A.1.36.0.0.12.0 have reached q = 1
# Subclones of clone A.1.21.0.1.1.0 have reached q = 1
# Subclones of clone A.1.89.0.0.1.0 have reached q = 1
# Subclones of clone A.1.89.0.0.3.0 have reached q = 1
# Subclones of clone A.1.89.0.0.3.1 have reached q = 1
# Subclones of clone A.1.89.0.0.3.2 have reached q = 1
# Subclones of clone A.1.89.0.1.1.0 have reached q = 1
# Subclones of clone A.1.4.3.0.2.0 have reached q = 1
# Subclones of clone A.1.4.7.0.0.0 have reached q = 1
# Subclones of clone A.1.89.1.0.5.0 have reached q = 1
# Subclones of clone A.1.89.1.0.6.0 have reached q = 1
# Subclones of clone A.1.89.1.1.1.0 have reached q = 1
# Subclones of clone A.1.89.1.1.2.0 have reached q = 1
# Subclones of clone A.1.42.1.0.1.0 have reached q = 1
# Subclones of clone A.1.289.0.0.1.0 have reached q = 1
# Subclones of clone A.1.63.0.3.0.0 have reached q = 1
# Subclones of clone A.1.11.0.0.1.0 have reached q = 1
# Subclones of clone A.1.11.0.0.1.1 have reached q = 1
# Subclones of clone A.1.8.0.0.1.1.0 have reached q = 1
# Subclones of clone A.1.8.0.0.1.1.1 have reached q = 1
# Subclones of clone A.1.8.0.0.1.1.2 have reached q = 1
# Subclones of clone A.1.8.0.0.1.1.3 have reached q = 1
# Subclones of clone A.1.8.0.0.1.2.0 have reached q = 1
# Subclones of clone A.1.101.0.0.0.1.0 have reached q = 1
# Subclones of clone A.1.101.0.0.0.2.0 have reached q = 1
# Subclones of clone A.1.101.0.0.0.2.1 have reached q = 1
# Subclones of clone A.1.101.0.0.0.4.0 have reached q = 1
# Subclones of clone A.1.101.0.0.0.4.1 have reached q = 1
# Subclones of clone A.1.49.6.0.0.0 have reached q = 1
# Subclones of clone A.1.21.0.31.0.0 have reached q = 1
# Subclones of clone A.1.21.0.38.0.0 have reached q = 1
# Subclones of clone A.1.21.0.39.0.0 have reached q = 1
# Subclones of clone A.1.21.0.40.0.0 have reached q = 1
# Subclones of clone A.1.21.0.41.0.0 have reached q = 1
# Subclones of clone A.1.63.0.22.0.0 have reached q = 1
# Subclones of clone A.1.63.0.22.0.1 have reached q = 1
# Subclones of clone A.1.89.1.5.0.0 have reached q = 1
# Subclones of clone A.1.8.4.0.0.0 have reached q = 1
# Subclones of clone A.1.8.0.0.2.0.0 have reached q = 1
# Subclones of clone A.1.8.0.0.2.0.1 have reached q = 1
# Subclones of clone A.1.8.0.0.2.0.2 have reached q = 1
# Subclones of clone A.1.8.0.0.3.0.0 have reached q = 1
# Subclones of clone A.1.8.0.0.3.0.1 have reached q = 1
# Subclones of clone A.1.8.0.0.3.0.2 have reached q = 1
# Subclones of clone A.1.8.0.0.3.1.0 have reached q = 1
# Subclones of clone A.1.8.0.0.3.1.1 have reached q = 1
# Subclones of clone A.1.8.0.0.3.1.2 have reached q = 1
# Subclones of clone A.1.8.0.0.3.1.3 have reached q = 1
# Subclones of clone A.1.8.0.0.3.2.0 have reached q = 1
# Subclones of clone A.1.36.0.0.1.0.0 have reached q = 1
# Subclones of clone A.1.36.0.0.1.0.1 have reached q = 1
# Subclones of clone A.1.36.0.0.1.0.2 have reached q = 1
# Subclones of clone A.1.36.0.0.1.0.3 have reached q = 1
# Subclones of clone A.1.36.0.0.1.1.0 have reached q = 1
# Subclones of clone A.1.36.0.0.1.1.1 have reached q = 1
# Subclones of clone A.1.36.0.0.1.1.2 have reached q = 1
# Subclones of clone A.1.21.16.0.1.0 have reached q = 1
# Subclones of clone A.1.21.16.0.1.1 have reached q = 1
# Subclones of clone A.1.21.22.0.0.0 have reached q = 1
# Subclones of clone A.1.21.22.0.0.1 have reached q = 1
# Subclones of clone A.1.21.22.0.1.0 have reached q = 1
# Subclones of clone A.1.63.0.0.2.0.0 have reached q = 1
# Subclones of clone A.1.63.0.0.2.1.0 have reached q = 1
# Subclones of clone A.1.63.0.0.2.1.1 have reached q = 1
# Subclones of clone A.1.63.0.0.2.1.2 have reached q = 1
# Subclones of clone A.1.63.0.0.2.1.3 have reached q = 1
# Subclones of clone A.1.63.0.0.3.0.0 have reached q = 1
# Subclones of clone A.1.63.0.0.3.0.1 have reached q = 1
# Subclones of clone A.1.289.0.0.0.0.0 have reached q = 1
# Subclones of clone A.1.289.0.0.0.0.1 have reached q = 1
# Subclones of clone A.1.289.0.0.0.0.2 have reached q = 1
# Subclones of clone A.1.63.0.2.0.0.0 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.0 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.2 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.0 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.1 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.2 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.3 have reached q = 1
# Subclones of clone A.1.63.0.0.0.0.0.0 have reached q = 1
# Subclones of clone A.1.63.0.0.0.0.1.0 have reached q = 1
# Subclones of clone A.1.63.0.0.0.0.2.0 have reached q = 1
# Subclones of clone A.1.63.0.0.0.0.2.1 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0 have reached q = 1
# Subclones of clone A.1.101.0.0.0.0 have reached q = 1
# Subclones of clone A.1.63.0.0.0.0 have reached q = 1
# Subclones of clone A.1.8.0.0.1.1 have reached q = 1
# Subclones of clone A.1.8.0.0.1.2 have reached q = 1
# Subclones of clone A.1.101.0.0.0.1 have reached q = 1
# Subclones of clone A.1.101.0.0.0.2 have reached q = 1
# Subclones of clone A.1.101.0.0.0.3 have reached q = 1
# Subclones of clone A.1.101.0.0.0.4 have reached q = 1
# Subclones of clone A.1.8.0.0.2.0 have reached q = 1
# Subclones of clone A.1.8.0.0.2.1 have reached q = 1
# Subclones of clone A.1.8.0.0.3.0 have reached q = 1
# Subclones of clone A.1.8.0.0.3.1 have reached q = 1
# Subclones of clone A.1.8.0.0.3.2 have reached q = 1
# Subclones of clone A.1.36.0.0.1.0 have reached q = 1
# Subclones of clone A.1.36.0.0.1.1 have reached q = 1
# Subclones of clone A.1.63.0.0.2.0 have reached q = 1
# Subclones of clone A.1.63.0.0.2.1 have reached q = 1
# Subclones of clone A.1.63.0.0.3.0 have reached q = 1
# Subclones of clone A.1.289.0.0.0.0 have reached q = 1
# Subclones of clone A.1.63.0.2.0.0 have reached q = 1
# Subclones of clone A.1.6.1.1.0.0 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0 have reached q = 1
# Subclones of clone A.1.63.0.0.0.0.0 have reached q = 1
# Subclones of clone A.1.63.0.0.0.0.1 have reached q = 1
# Subclones of clone A.1.63.0.0.0.0.2 have reached q = 1
# Subclones of clone A.1.21.0.0.0.0 have reached q = 1
# Subclones of clone A.1.21.0.0.0.1 have reached q = 1
# Subclones of clone A.1.21.0.0.0.2 have reached q = 1
# Subclones of clone A.1.8.0.0.0.0 have reached q = 1
# Subclones of clone A.1.8.0.0.1.3 have reached q = 1
# Subclones of clone A.1.8.0.0.1.4 have reached q = 1
# Subclones of clone A.1.8.0.0.1.5 have reached q = 1
# Subclones of clone A.1.101.0.0.0.5 have reached q = 1
# Subclones of clone A.1.42.1.0.0.0 have reached q = 1
# Subclones of clone A.1.8.0.0.2.2 have reached q = 1
# Subclones of clone A.1.8.0.0.3.3 have reached q = 1
# Subclones of clone A.1.36.0.0.1.2 have reached q = 1
# Subclones of clone A.1.36.0.0.1.3 have reached q = 1
# Subclones of clone A.1.36.0.0.1.4 have reached q = 1
# Subclones of clone A.1.36.0.0.1.5 have reached q = 1
# Subclones of clone A.1.36.0.0.1.6 have reached q = 1
# Subclones of clone A.1.36.0.0.2.0 have reached q = 1
# Subclones of clone A.1.36.0.0.2.1 have reached q = 1
# Subclones of clone A.1.36.0.0.4.0 have reached q = 1
# Subclones of clone A.1.36.0.0.4.1 have reached q = 1
# Subclones of clone A.1.36.0.0.4.2 have reached q = 1
# Subclones of clone A.1.21.0.1.0.0 have reached q = 1
# Subclones of clone A.1.63.0.0.2.2 have reached q = 1
# Subclones of clone A.1.63.0.0.2.3 have reached q = 1
# Subclones of clone A.1.63.0.0.2.4 have reached q = 1
# Subclones of clone A.1.63.0.0.2.5 have reached q = 1
# Subclones of clone A.1.4.3.0.1.0 have reached q = 1
# Subclones of clone A.1.89.1.1.0.0 have reached q = 1
# Subclones of clone A.1.89.1.1.0.1 have reached q = 1
# Subclones of clone A.1.89.1.1.0.2 have reached q = 1
# Subclones of clone A.1.141.0.0.0.0 have reached q = 1
# Subclones of clone A.1.289.0.0.0.1 have reached q = 1
# Subclones of clone A.1.289.0.0.0.2 have reached q = 1
# Subclones of clone A.1.63.0.2.0.1 have reached q = 1
# Subclones of clone A.1.2.0.0.0.0 have reached q = 1
# Subclones of clone A.1.6.1.0.0.0 have reached q = 1
# Subclones of clone A.1.6.1.0.0.1 have reached q = 1
# Subclones of clone A.1.6.1.0.0.2 have reached q = 1
# Subclones of clone A.1.6.1.1.0.1 have reached q = 1
# Subclones of clone A.1.6.1.1.0.2 have reached q = 1
# Subclones of clone A.1.6.1.1.0.3 have reached q = 1
# Subclones of clone A.1.6.1.1.0.4 have reached q = 1
# Subclones of clone A.1.101.0.0.0.0.0 have reached q = 1
# Subclones of clone A.1.101.0.0.0.0.1 have reached q = 1
# Subclones of clone A.1.21.0.0.1.0 have reached q = 1
# Subclones of clone A.1.8.0.0.4.0 have reached q = 1
# Subclones of clone A.1.8.0.0.6.0 have reached q = 1
# Subclones of clone A.1.101.0.0.3.0 have reached q = 1
# Subclones of clone A.1.36.0.0.11.0 have reached q = 1
# Subclones of clone A.1.36.0.0.12.0 have reached q = 1
# Subclones of clone A.1.21.0.1.1.0 have reached q = 1
# Subclones of clone A.1.89.0.0.1.0 have reached q = 1
# Subclones of clone A.1.89.0.0.3.0 have reached q = 1
# Subclones of clone A.1.89.0.0.3.1 have reached q = 1
# Subclones of clone A.1.89.0.0.3.2 have reached q = 1
# Subclones of clone A.1.89.0.1.1.0 have reached q = 1
# Subclones of clone A.1.4.3.0.2.0 have reached q = 1
# Subclones of clone A.1.4.7.0.0.0 have reached q = 1
# Subclones of clone A.1.89.1.0.5.0 have reached q = 1
# Subclones of clone A.1.89.1.0.6.0 have reached q = 1
# Subclones of clone A.1.89.1.1.1.0 have reached q = 1
# Subclones of clone A.1.89.1.1.2.0 have reached q = 1
# Subclones of clone A.1.42.1.0.1.0 have reached q = 1
# Subclones of clone A.1.289.0.0.1.0 have reached q = 1
# Subclones of clone A.1.63.0.3.0.0 have reached q = 1
# Subclones of clone A.1.11.0.0.1.0 have reached q = 1
# Subclones of clone A.1.11.0.0.1.1 have reached q = 1
# Subclones of clone A.1.8.0.0.1.1.0 have reached q = 1
# Subclones of clone A.1.8.0.0.1.1.1 have reached q = 1
# Subclones of clone A.1.8.0.0.1.1.2 have reached q = 1
# Subclones of clone A.1.8.0.0.1.1.3 have reached q = 1
# Subclones of clone A.1.8.0.0.1.2.0 have reached q = 1
# Subclones of clone A.1.101.0.0.0.1.0 have reached q = 1
# Subclones of clone A.1.101.0.0.0.2.0 have reached q = 1
# Subclones of clone A.1.101.0.0.0.2.1 have reached q = 1
# Subclones of clone A.1.101.0.0.0.4.0 have reached q = 1
# Subclones of clone A.1.101.0.0.0.4.1 have reached q = 1
# Subclones of clone A.1.49.6.0.0.0 have reached q = 1
# Subclones of clone A.1.21.0.31.0.0 have reached q = 1
# Subclones of clone A.1.21.0.38.0.0 have reached q = 1
# Subclones of clone A.1.21.0.39.0.0 have reached q = 1
# Subclones of clone A.1.21.0.40.0.0 have reached q = 1
# Subclones of clone A.1.21.0.41.0.0 have reached q = 1
# Subclones of clone A.1.63.0.22.0.0 have reached q = 1
# Subclones of clone A.1.63.0.22.0.1 have reached q = 1
# Subclones of clone A.1.89.1.5.0.0 have reached q = 1
# Subclones of clone A.1.8.4.0.0.0 have reached q = 1
# Subclones of clone A.1.8.0.0.2.0.0 have reached q = 1
# Subclones of clone A.1.8.0.0.2.0.1 have reached q = 1
# Subclones of clone A.1.8.0.0.2.0.2 have reached q = 1
# Subclones of clone A.1.8.0.0.3.0.0 have reached q = 1
# Subclones of clone A.1.8.0.0.3.0.1 have reached q = 1
# Subclones of clone A.1.8.0.0.3.0.2 have reached q = 1
# Subclones of clone A.1.8.0.0.3.1.0 have reached q = 1
# Subclones of clone A.1.8.0.0.3.1.1 have reached q = 1
# Subclones of clone A.1.8.0.0.3.1.2 have reached q = 1
# Subclones of clone A.1.8.0.0.3.1.3 have reached q = 1
# Subclones of clone A.1.8.0.0.3.2.0 have reached q = 1
# Subclones of clone A.1.36.0.0.1.0.0 have reached q = 1
# Subclones of clone A.1.36.0.0.1.0.1 have reached q = 1
# Subclones of clone A.1.36.0.0.1.0.2 have reached q = 1
# Subclones of clone A.1.36.0.0.1.0.3 have reached q = 1
# Subclones of clone A.1.36.0.0.1.1.0 have reached q = 1
# Subclones of clone A.1.36.0.0.1.1.1 have reached q = 1
# Subclones of clone A.1.36.0.0.1.1.2 have reached q = 1
# Subclones of clone A.1.21.16.0.1.0 have reached q = 1
# Subclones of clone A.1.21.16.0.1.1 have reached q = 1
# Subclones of clone A.1.21.22.0.0.0 have reached q = 1
# Subclones of clone A.1.21.22.0.0.1 have reached q = 1
# Subclones of clone A.1.21.22.0.1.0 have reached q = 1
# Subclones of clone A.1.63.0.0.2.0.0 have reached q = 1
# Subclones of clone A.1.63.0.0.2.1.0 have reached q = 1
# Subclones of clone A.1.63.0.0.2.1.1 have reached q = 1
# Subclones of clone A.1.63.0.0.2.1.2 have reached q = 1
# Subclones of clone A.1.63.0.0.2.1.3 have reached q = 1
# Subclones of clone A.1.63.0.0.3.0.0 have reached q = 1
# Subclones of clone A.1.63.0.0.3.0.1 have reached q = 1
# Subclones of clone A.1.289.0.0.0.0.0 have reached q = 1
# Subclones of clone A.1.289.0.0.0.0.1 have reached q = 1
# Subclones of clone A.1.289.0.0.0.0.2 have reached q = 1
# Subclones of clone A.1.63.0.2.0.0.0 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.0 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.2 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.0 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.1 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.2 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.3 have reached q = 1
# Subclones of clone A.1.63.0.0.0.0.0.0 have reached q = 1
# Subclones of clone A.1.63.0.0.0.0.1.0 have reached q = 1
# Subclones of clone A.1.63.0.0.0.0.2.0 have reached q = 1
# Subclones of clone A.1.63.0.0.0.0.2.1 have reached q = 1
# Subclones of clone A.1.21.0.0.0.3 have reached q = 1
# Subclones of clone A.1.21.0.0.0.4 have reached q = 1
# Subclones of clone A.1.8.0.0.1.6 have reached q = 1
# Subclones of clone A.1.8.0.0.1.7 have reached q = 1
# Subclones of clone A.1.8.0.0.1.8 have reached q = 1
# Subclones of clone A.1.8.0.0.1.9 have reached q = 1
# Subclones of clone A.1.8.0.0.1.10 have reached q = 1
# Subclones of clone A.1.8.0.0.1.11 have reached q = 1
# Subclones of clone A.1.8.0.0.1.12 have reached q = 1
# Subclones of clone A.1.8.0.0.1.13 have reached q = 1
# Subclones of clone A.1.8.0.0.1.14 have reached q = 1
# Subclones of clone A.1.8.0.0.1.15 have reached q = 1
# Subclones of clone A.1.8.0.0.1.16 have reached q = 1
# Subclones of clone A.1.8.0.0.1.17 have reached q = 1
# Subclones of clone A.1.8.0.0.1.18 have reached q = 1
# Subclones of clone A.1.8.0.0.1.19 have reached q = 1
# Subclones of clone A.1.8.0.0.1.20 have reached q = 1
# Subclones of clone A.1.101.0.0.0.6 have reached q = 1
# Subclones of clone A.1.101.0.0.0.7 have reached q = 1
# Subclones of clone A.1.101.0.0.0.8 have reached q = 1
# Subclones of clone A.1.101.0.0.0.9 have reached q = 1
# Subclones of clone A.1.101.0.0.0.10 have reached q = 1
# Subclones of clone A.1.101.0.0.0.11 have reached q = 1
# Subclones of clone A.1.42.1.0.0.1 have reached q = 1
# Subclones of clone A.1.42.1.0.0.2 have reached q = 1
# Subclones of clone A.1.42.1.0.0.3 have reached q = 1
# Subclones of clone A.1.42.1.0.0.4 have reached q = 1
# Subclones of clone A.1.42.1.0.0.5 have reached q = 1
# Subclones of clone A.1.8.0.0.3.4 have reached q = 1
# Subclones of clone A.1.36.0.0.1.7 have reached q = 1
# Subclones of clone A.1.36.0.0.1.8 have reached q = 1
# Subclones of clone A.1.36.0.0.1.9 have reached q = 1
# Subclones of clone A.1.36.0.0.1.10 have reached q = 1
# Subclones of clone A.1.36.0.0.1.11 have reached q = 1
# Subclones of clone A.1.36.0.0.2.2 have reached q = 1
# Subclones of clone A.1.36.0.0.3.0 have reached q = 1
# Subclones of clone A.1.36.0.0.3.1 have reached q = 1
# Subclones of clone A.1.36.0.0.3.2 have reached q = 1
# Subclones of clone A.1.36.0.0.4.3 have reached q = 1
# Subclones of clone A.1.36.0.0.4.4 have reached q = 1
# Subclones of clone A.1.36.0.0.4.5 have reached q = 1
# Subclones of clone A.1.36.0.0.4.6 have reached q = 1
# Subclones of clone A.1.21.0.1.0.1 have reached q = 1
# Subclones of clone A.1.21.0.1.0.2 have reached q = 1
# Subclones of clone A.1.63.0.0.2.6 have reached q = 1
# Subclones of clone A.1.63.0.0.2.7 have reached q = 1
# Subclones of clone A.1.63.0.0.3.1 have reached q = 1
# Subclones of clone A.1.63.0.0.3.2 have reached q = 1
# Subclones of clone A.1.63.0.0.3.3 have reached q = 1
# Subclones of clone A.1.63.0.0.3.4 have reached q = 1
# Subclones of clone A.1.63.0.0.3.5 have reached q = 1
# Subclones of clone A.1.63.0.0.3.6 have reached q = 1
# Subclones of clone A.1.63.0.0.3.7 have reached q = 1
# Subclones of clone A.1.63.0.0.3.8 have reached q = 1
# Subclones of clone A.1.63.0.0.4.0 have reached q = 1
# Subclones of clone A.1.63.0.0.4.1 have reached q = 1
# Subclones of clone A.1.63.0.0.4.2 have reached q = 1
# Subclones of clone A.1.63.0.0.4.3 have reached q = 1
# Subclones of clone A.1.4.3.0.1.1 have reached q = 1
# Subclones of clone A.1.4.3.0.1.2 have reached q = 1
# Subclones of clone A.1.89.1.1.0.3 have reached q = 1
# Subclones of clone A.1.89.1.1.0.4 have reached q = 1
# Subclones of clone A.1.89.1.1.0.5 have reached q = 1
# Subclones of clone A.1.89.1.1.0.6 have reached q = 1
# Subclones of clone A.1.89.1.1.0.7 have reached q = 1
# Subclones of clone A.1.89.1.1.0.8 have reached q = 1
# Subclones of clone A.1.89.1.1.0.9 have reached q = 1
# Subclones of clone A.1.89.1.1.0.10 have reached q = 1
# Subclones of clone A.1.89.1.1.0.11 have reached q = 1
# Subclones of clone A.1.89.1.1.0.12 have reached q = 1
# Subclones of clone A.1.89.1.1.0.13 have reached q = 1
# Subclones of clone A.1.89.1.1.0.14 have reached q = 1
# Subclones of clone A.1.289.0.0.0.3 have reached q = 1
# Subclones of clone A.1.289.0.0.0.4 have reached q = 1
# Subclones of clone A.1.289.0.0.0.5 have reached q = 1
# Subclones of clone A.1.289.0.0.0.6 have reached q = 1
# Subclones of clone A.1.289.0.0.0.7 have reached q = 1
# Subclones of clone A.1.289.0.0.0.8 have reached q = 1
# Subclones of clone A.1.289.0.0.0.9 have reached q = 1
# Subclones of clone A.1.289.0.0.0.10 have reached q = 1
# Subclones of clone A.1.289.0.0.0.11 have reached q = 1
# Subclones of clone A.1.289.0.0.0.12 have reached q = 1
# Subclones of clone A.1.289.0.0.0.13 have reached q = 1
# Subclones of clone A.1.289.0.0.0.14 have reached q = 1
# Subclones of clone A.1.289.0.0.0.15 have reached q = 1
# Subclones of clone A.1.289.0.0.0.16 have reached q = 1
# Subclones of clone A.1.63.0.2.0.2 have reached q = 1
# Subclones of clone A.1.63.0.2.0.3 have reached q = 1
# Subclones of clone A.1.63.0.2.0.4 have reached q = 1
# Subclones of clone A.1.63.0.2.0.5 have reached q = 1
# Subclones of clone A.1.63.0.2.0.6 have reached q = 1
# Subclones of clone A.1.2.0.0.0.1 have reached q = 1
# Subclones of clone A.1.2.0.0.0.2 have reached q = 1
# Subclones of clone A.1.2.0.0.0.3 have reached q = 1
# Subclones of clone A.1.6.1.0.0.3 have reached q = 1
# Subclones of clone A.1.6.1.0.0.4 have reached q = 1
# Subclones of clone A.1.6.1.1.0.5 have reached q = 1
# Subclones of clone A.1.6.1.1.0.6 have reached q = 1
# Subclones of clone A.1.6.1.1.0.7 have reached q = 1
# Subclones of clone A.1.6.1.1.0.8 have reached q = 1
# Subclones of clone A.1.12.0.0.0.1 have reached q = 1
# Subclones of clone A.1.101.0.0.0.0.2 have reached q = 1
# Subclones of clone A.1.101.0.0.0.0.3 have reached q = 1
# Subclones of clone A.1.101.0.0.0.0.4 have reached q = 1
# Subclones of clone A.1.101.0.0.0.0.5 have reached q = 1
# Subclones of clone A.1.21.0.0.2.0 have reached q = 1
# Subclones of clone A.1.8.0.0.5.0 have reached q = 1
# Subclones of clone A.1.8.0.0.5.1 have reached q = 1
# Subclones of clone A.1.8.0.0.6.1 have reached q = 1
# Subclones of clone A.1.101.0.0.1.0 have reached q = 1
# Subclones of clone A.1.101.0.0.2.0 have reached q = 1
# Subclones of clone A.1.101.0.0.5.0 have reached q = 1
# Subclones of clone A.1.101.0.0.5.1 have reached q = 1
# Subclones of clone A.1.101.0.0.5.2 have reached q = 1
# Subclones of clone A.1.36.0.0.5.0 have reached q = 1
# Subclones of clone A.1.36.0.0.8.0 have reached q = 1
# Subclones of clone A.1.36.0.0.8.1 have reached q = 1
# Subclones of clone A.1.36.0.0.8.2 have reached q = 1
# Subclones of clone A.1.36.0.0.9.0 have reached q = 1
# Subclones of clone A.1.36.0.0.9.1 have reached q = 1
# Subclones of clone A.1.36.0.0.9.2 have reached q = 1
# Subclones of clone A.1.36.0.0.9.3 have reached q = 1
# Subclones of clone A.1.36.0.0.11.1 have reached q = 1
# Subclones of clone A.1.36.0.0.12.1 have reached q = 1
# Subclones of clone A.1.36.0.0.12.2 have reached q = 1
# Subclones of clone A.1.36.0.0.13.0 have reached q = 1
# Subclones of clone A.1.89.0.0.0.0 have reached q = 1
# Subclones of clone A.1.89.0.0.2.0 have reached q = 1
# Subclones of clone A.1.89.0.0.3.3 have reached q = 1
# Subclones of clone A.1.89.0.0.4.0 have reached q = 1
# Subclones of clone A.1.89.0.1.0.0 have reached q = 1
# Subclones of clone A.1.89.0.1.0.1 have reached q = 1
# Subclones of clone A.1.89.0.1.0.2 have reached q = 1
# Subclones of clone A.1.89.0.1.1.1 have reached q = 1
# Subclones of clone A.1.4.3.0.2.1 have reached q = 1
# Subclones of clone A.1.4.3.0.2.2 have reached q = 1
# Subclones of clone A.1.89.1.0.0.0 have reached q = 1
# Subclones of clone A.1.89.1.0.0.1 have reached q = 1
# Subclones of clone A.1.89.1.0.0.2 have reached q = 1
# Subclones of clone A.1.89.1.0.0.3 have reached q = 1
# Subclones of clone A.1.89.1.0.1.0 have reached q = 1
# Subclones of clone A.1.89.1.0.2.0 have reached q = 1
# Subclones of clone A.1.89.1.0.2.1 have reached q = 1
# Subclones of clone A.1.89.1.0.3.0 have reached q = 1
# Subclones of clone A.1.89.1.0.3.1 have reached q = 1
# Subclones of clone A.1.89.1.0.6.1 have reached q = 1
# Subclones of clone A.1.89.1.1.2.1 have reached q = 1
# Subclones of clone A.1.42.1.0.1.1 have reached q = 1
# Subclones of clone A.1.289.0.0.1.1 have reached q = 1
# Subclones of clone A.1.289.0.0.3.0 have reached q = 1
# Subclones of clone A.1.289.0.0.3.1 have reached q = 1
# Subclones of clone A.1.289.0.0.3.2 have reached q = 1
# Subclones of clone A.1.289.0.0.3.3 have reached q = 1
# Subclones of clone A.1.289.0.0.3.4 have reached q = 1
# Subclones of clone A.1.289.0.0.3.5 have reached q = 1
# Subclones of clone A.1.21.0.8.0.0 have reached q = 1
# Subclones of clone A.1.21.0.10.0.0 have reached q = 1
# Subclones of clone A.1.63.0.3.0.1 have reached q = 1
# Subclones of clone A.1.89.0.2.0.0 have reached q = 1
# Subclones of clone A.1.11.0.0.0.0 have reached q = 1
# Subclones of clone A.1.11.0.0.0.1 have reached q = 1
# Subclones of clone A.1.11.0.0.1.2 have reached q = 1
# Subclones of clone A.1.11.0.0.2.0 have reached q = 1
# Subclones of clone A.1.11.0.0.2.1 have reached q = 1
# Subclones of clone A.1.12.0.0.1.0 have reached q = 1
# Subclones of clone A.1.12.0.0.2.0 have reached q = 1
# Subclones of clone A.1.12.0.0.2.1 have reached q = 1
# Subclones of clone A.1.8.0.0.1.1.4 have reached q = 1
# Subclones of clone A.1.8.0.0.1.1.5 have reached q = 1
# Subclones of clone A.1.8.0.0.1.2.1 have reached q = 1
# Subclones of clone A.1.8.0.0.1.2.2 have reached q = 1
# Subclones of clone A.1.101.0.0.0.2.2 have reached q = 1
# Subclones of clone A.1.49.6.0.0.1 have reached q = 1
# Subclones of clone A.1.49.6.0.0.2 have reached q = 1
# Subclones of clone A.1.21.0.14.0.0 have reached q = 1
# Subclones of clone A.1.21.0.19.0.0 have reached q = 1
# Subclones of clone A.1.21.0.31.0.1 have reached q = 1
# Subclones of clone A.1.21.0.31.0.2 have reached q = 1
# Subclones of clone A.1.21.0.31.1.0 have reached q = 1
# Subclones of clone A.1.21.0.31.1.1 have reached q = 1
# Subclones of clone A.1.21.0.31.1.2 have reached q = 1
# Subclones of clone A.1.21.0.33.0.0 have reached q = 1
# Subclones of clone A.1.21.0.38.0.1 have reached q = 1
# Subclones of clone A.1.21.0.39.0.1 have reached q = 1
# Subclones of clone A.1.21.0.40.0.1 have reached q = 1
# Subclones of clone A.1.21.0.40.0.2 have reached q = 1
# Subclones of clone A.1.21.0.40.0.3 have reached q = 1
# Subclones of clone A.1.21.0.40.0.4 have reached q = 1
# Subclones of clone A.1.21.0.40.0.5 have reached q = 1
# Subclones of clone A.1.21.0.41.0.1 have reached q = 1
# Subclones of clone A.1.21.0.44.0.0 have reached q = 1
# Subclones of clone A.1.21.0.44.0.1 have reached q = 1
# Subclones of clone A.1.21.0.44.0.2 have reached q = 1
# Subclones of clone A.1.21.0.44.0.3 have reached q = 1
# Subclones of clone A.1.63.0.17.0.0 have reached q = 1
# Subclones of clone A.1.63.0.19.0.0 have reached q = 1
# Subclones of clone A.1.63.0.22.0.2 have reached q = 1
# Subclones of clone A.1.63.0.22.0.3 have reached q = 1
# Subclones of clone A.1.63.0.22.0.4 have reached q = 1
# Subclones of clone A.1.6.2.0.0.0 have reached q = 1
# Subclones of clone A.1.6.2.0.0.1 have reached q = 1
# Subclones of clone A.1.89.1.5.0.1 have reached q = 1
# Subclones of clone A.1.89.1.5.0.2 have reached q = 1
# Subclones of clone A.1.89.1.5.0.3 have reached q = 1
# Subclones of clone A.1.89.1.5.1.0 have reached q = 1
# Subclones of clone A.1.42.3.2.0.0 have reached q = 1
# Subclones of clone A.1.97.0.0.0.0 have reached q = 1
# Subclones of clone A.1.97.0.0.0.1 have reached q = 1
# Subclones of clone A.1.8.0.0.2.0.3 have reached q = 1
# Subclones of clone A.1.8.0.0.3.0.3 have reached q = 1
# Subclones of clone A.1.8.0.0.3.0.4 have reached q = 1
# Subclones of clone A.1.36.0.0.1.0.4 have reached q = 1
# Subclones of clone A.1.36.0.0.1.1.3 have reached q = 1
# Subclones of clone A.1.36.0.0.1.1.4 have reached q = 1
# Subclones of clone A.1.36.0.0.1.1.5 have reached q = 1
# Subclones of clone A.1.36.0.0.1.1.6 have reached q = 1
# Subclones of clone A.1.36.0.0.1.1.7 have reached q = 1
# Subclones of clone A.1.21.16.0.0.0 have reached q = 1
# Subclones of clone A.1.21.16.0.0.1 have reached q = 1
# Subclones of clone A.1.21.16.0.0.2 have reached q = 1
# Subclones of clone A.1.21.16.0.0.3 have reached q = 1
# Subclones of clone A.1.21.16.0.0.4 have reached q = 1
# Subclones of clone A.1.21.22.0.0.2 have reached q = 1
# Subclones of clone A.1.21.22.0.0.3 have reached q = 1
# Subclones of clone A.1.21.22.0.0.4 have reached q = 1
# Subclones of clone A.1.21.22.0.0.5 have reached q = 1
# Subclones of clone A.1.21.22.0.1.1 have reached q = 1
# Subclones of clone A.1.21.22.0.1.2 have reached q = 1
# Subclones of clone A.1.21.22.0.1.3 have reached q = 1
# Subclones of clone A.1.21.22.0.1.4 have reached q = 1
# Subclones of clone A.1.21.22.0.1.5 have reached q = 1
# Subclones of clone A.1.21.22.0.1.6 have reached q = 1
# Subclones of clone A.1.63.0.0.2.1.4 have reached q = 1
# Subclones of clone A.1.63.0.0.2.1.5 have reached q = 1
# Subclones of clone A.1.63.0.0.3.0.2 have reached q = 1
# Subclones of clone A.1.63.0.0.3.0.3 have reached q = 1
# Subclones of clone A.1.63.0.0.3.0.4 have reached q = 1
# Subclones of clone A.1.289.0.0.0.0.3 have reached q = 1
# Subclones of clone A.1.289.0.0.0.0.4 have reached q = 1
# Subclones of clone A.1.289.0.0.0.0.5 have reached q = 1
# Subclones of clone A.1.289.0.0.0.0.6 have reached q = 1
# Subclones of clone A.1.13.9.0.0.0 have reached q = 1
# Subclones of clone A.1.109.9.0.0.0 have reached q = 1
# Subclones of clone A.1.109.9.0.0.1 have reached q = 1
# Subclones of clone A.1.63.0.2.0.0.1 have reached q = 1
# Subclones of clone A.1.63.0.2.0.0.2 have reached q = 1
# Subclones of clone A.1.6.1.1.0.0.0 have reached q = 1
# Subclones of clone A.1.6.1.1.0.0.1 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.3 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.4 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.5 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.6 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.7 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.8 have reached q = 1
# Subclones of clone A.1.63.0.0.0.0.2.2 have reached q = 1
# Subclones of clone A.1.8.0.0.11.0 have reached q = 1
# Subclones of clone A.1.8.0.0.15.0 have reached q = 1
# Subclones of clone A.1.8.0.0.16.0 have reached q = 1
# Subclones of clone A.1.8.0.0.22.0 have reached q = 1
# Subclones of clone A.1.8.0.0.23.0 have reached q = 1
# Subclones of clone A.1.8.0.0.27.0 have reached q = 1
# Subclones of clone A.1.101.0.0.10.0 have reached q = 1
# Subclones of clone A.1.101.0.0.11.0 have reached q = 1
# Subclones of clone A.1.101.0.0.12.0 have reached q = 1
# Subclones of clone A.1.101.0.0.13.0 have reached q = 1
# Subclones of clone A.1.101.0.0.14.0 have reached q = 1
# Subclones of clone A.1.101.0.0.14.1 have reached q = 1
# Subclones of clone A.1.36.0.0.15.0 have reached q = 1
# Subclones of clone A.1.36.0.0.15.1 have reached q = 1
# Subclones of clone A.1.36.0.0.21.0 have reached q = 1
# Subclones of clone A.1.36.0.0.22.0 have reached q = 1
# Subclones of clone A.1.21.0.1.2.0 have reached q = 1
# Subclones of clone A.1.63.0.0.6.0 have reached q = 1
# Subclones of clone A.1.63.0.0.6.1 have reached q = 1
# Subclones of clone A.1.63.0.1.2.0 have reached q = 1
# Subclones of clone A.1.63.0.1.2.1 have reached q = 1
# Subclones of clone A.1.89.0.0.5.0 have reached q = 1
# Subclones of clone A.1.89.0.0.6.0 have reached q = 1
# Subclones of clone A.1.89.0.0.9.0 have reached q = 1
# Subclones of clone A.1.89.0.0.10.0 have reached q = 1
# Subclones of clone A.1.89.0.0.12.0 have reached q = 1
# Subclones of clone A.1.89.0.0.12.1 have reached q = 1
# Subclones of clone A.1.89.0.1.3.0 have reached q = 1
# Subclones of clone A.1.89.0.1.4.0 have reached q = 1
# Subclones of clone A.1.89.0.1.5.0 have reached q = 1
# Subclones of clone A.1.89.0.1.6.0 have reached q = 1
# Subclones of clone A.1.89.0.1.8.0 have reached q = 1
# Subclones of clone A.1.89.0.1.8.1 have reached q = 1
# Subclones of clone A.1.89.0.1.9.0 have reached q = 1
# Subclones of clone A.1.89.0.1.11.0 have reached q = 1
# Subclones of clone A.1.101.0.1.3.0 have reached q = 1
# Subclones of clone A.1.101.0.1.3.1 have reached q = 1
# Subclones of clone A.1.4.3.0.3.0 have reached q = 1
# Subclones of clone A.1.4.3.0.5.0 have reached q = 1
# Subclones of clone A.1.4.3.0.5.1 have reached q = 1
# Subclones of clone A.1.4.3.0.6.0 have reached q = 1
# Subclones of clone A.1.4.3.0.7.0 have reached q = 1
# Subclones of clone A.1.4.3.0.9.0 have reached q = 1
# Subclones of clone A.1.89.1.0.8.0 have reached q = 1
# Subclones of clone A.1.89.1.0.9.0 have reached q = 1
# Subclones of clone A.1.89.1.0.12.0 have reached q = 1
# Subclones of clone A.1.89.1.1.5.0 have reached q = 1
# Subclones of clone A.1.89.1.1.5.1 have reached q = 1
# Subclones of clone A.1.89.1.1.7.0 have reached q = 1
# Subclones of clone A.1.89.1.1.7.1 have reached q = 1
# Subclones of clone A.1.89.1.1.11.0 have reached q = 1
# Subclones of clone A.1.89.1.1.13.0 have reached q = 1
# Subclones of clone A.1.89.1.1.14.0 have reached q = 1
# Subclones of clone A.1.89.1.1.17.0 have reached q = 1
# Subclones of clone A.1.89.1.1.19.0 have reached q = 1
# Subclones of clone A.1.89.1.1.22.0 have reached q = 1
# Subclones of clone A.1.89.1.1.23.0 have reached q = 1
# Subclones of clone A.1.89.1.1.26.0 have reached q = 1
# Subclones of clone A.1.89.1.1.28.0 have reached q = 1
# Subclones of clone A.1.89.1.1.34.0 have reached q = 1
# Subclones of clone A.1.89.1.1.35.0 have reached q = 1
# Subclones of clone A.1.89.1.1.38.0 have reached q = 1
# Subclones of clone A.1.89.1.1.39.0 have reached q = 1
# Subclones of clone A.1.42.1.0.4.0 have reached q = 1
# Subclones of clone A.1.42.1.0.4.1 have reached q = 1
# Subclones of clone A.1.289.0.0.5.0 have reached q = 1
# Subclones of clone A.1.289.0.0.5.1 have reached q = 1
# Subclones of clone A.1.4.2.0.0.0 have reached q = 1
# Subclones of clone A.1.8.0.1.1.0 have reached q = 1
# Subclones of clone A.1.21.0.2.0.0 have reached q = 1
# Subclones of clone A.1.21.0.3.0.0 have reached q = 1
# Subclones of clone A.1.21.0.6.0.0 have reached q = 1
# Subclones of clone A.1.21.0.6.0.1 have reached q = 1
# Subclones of clone A.1.21.0.7.0.0 have reached q = 1
# Subclones of clone A.1.21.0.7.1.0 have reached q = 1
# Subclones of clone A.1.21.0.7.2.0 have reached q = 1
# Subclones of clone A.1.21.0.7.4.0 have reached q = 1
# Subclones of clone A.1.21.0.8.2.0 have reached q = 1
# Subclones of clone A.1.21.0.9.0.0 have reached q = 1
# Subclones of clone A.1.21.0.9.0.1 have reached q = 1
# Subclones of clone A.1.21.0.10.1.0 have reached q = 1
# Subclones of clone A.1.63.0.5.0.0 have reached q = 1
# Subclones of clone A.1.89.0.2.2.0 have reached q = 1
# Subclones of clone A.1.89.0.2.2.1 have reached q = 1
# Subclones of clone A.1.89.0.2.7.0 have reached q = 1
# Subclones of clone A.1.101.0.5.1.0 have reached q = 1
# Subclones of clone A.1.6.1.1.2.0 have reached q = 1
# Subclones of clone A.1.11.0.0.3.0 have reached q = 1
# Subclones of clone A.1.11.0.1.1.0 have reached q = 1
# Subclones of clone A.1.11.0.1.1.1 have reached q = 1
# Subclones of clone A.1.89.1.2.1.0 have reached q = 1
# Subclones of clone A.1.89.1.3.1.0 have reached q = 1
# Subclones of clone A.1.89.1.3.1.1 have reached q = 1
# Subclones of clone A.1.21.0.0.0.0.0 have reached q = 1
# Subclones of clone A.1.21.0.0.0.0.1 have reached q = 1
# Subclones of clone A.1.21.0.0.0.1.0 have reached q = 1
# Subclones of clone A.1.21.0.0.0.1.1 have reached q = 1
# Subclones of clone A.1.21.0.0.0.1.2 have reached q = 1
# Subclones of clone A.1.21.0.0.0.2.0 have reached q = 1
# Subclones of clone A.1.21.0.0.0.2.1 have reached q = 1
# Subclones of clone A.1.21.0.0.0.2.2 have reached q = 1
# Subclones of clone A.1.12.0.0.5.0 have reached q = 1
# Subclones of clone A.1.12.0.0.7.0 have reached q = 1
# Subclones of clone A.1.12.0.0.7.1 have reached q = 1
# Subclones of clone A.1.12.0.0.8.0 have reached q = 1
# Subclones of clone A.1.12.0.0.9.0 have reached q = 1
# Subclones of clone A.1.42.2.0.0.0 have reached q = 1
# Subclones of clone A.1.8.0.0.1.3.0 have reached q = 1
# Subclones of clone A.1.101.0.0.0.5.0 have reached q = 1
# Subclones of clone A.1.49.6.0.2.0 have reached q = 1
# Subclones of clone A.1.145.0.0.0.0 have reached q = 1
# Subclones of clone A.1.145.0.0.0.1 have reached q = 1
# Subclones of clone A.1.8.0.4.0.0 have reached q = 1
# Subclones of clone A.1.21.0.18.0.0 have reached q = 1
# Subclones of clone A.1.21.0.20.0.0 have reached q = 1
# Subclones of clone A.1.21.0.22.0.0 have reached q = 1
# Subclones of clone A.1.21.0.25.0.0 have reached q = 1
# Subclones of clone A.1.21.0.26.0.0 have reached q = 1
# Subclones of clone A.1.21.0.26.0.1 have reached q = 1
# Subclones of clone A.1.21.0.26.0.2 have reached q = 1
# Subclones of clone A.1.21.0.27.2.0 have reached q = 1
# Subclones of clone A.1.21.0.30.0.0 have reached q = 1
# Subclones of clone A.1.21.0.30.0.1 have reached q = 1
# Subclones of clone A.1.21.0.42.0.0 have reached q = 1
# Subclones of clone A.1.21.0.43.0.0 have reached q = 1
# Subclones of clone A.1.21.0.43.0.1 have reached q = 1
# Subclones of clone A.1.21.0.43.0.2 have reached q = 1
# Subclones of clone A.1.33.0.2.0.0 have reached q = 1
# Subclones of clone A.1.63.0.16.0.0 have reached q = 1
# Subclones of clone A.1.63.0.16.2.0 have reached q = 1
# Subclones of clone A.1.89.0.7.0.0 have reached q = 1
# Subclones of clone A.1.89.0.7.0.1 have reached q = 1
# Subclones of clone A.1.101.0.10.0.0 have reached q = 1
# Subclones of clone A.1.101.0.10.0.1 have reached q = 1
# Subclones of clone A.1.8.1.0.1.0 have reached q = 1
# Subclones of clone A.1.8.1.0.1.1 have reached q = 1
# Subclones of clone A.1.89.1.6.0.0 have reached q = 1
# Subclones of clone A.1.4.18.1.0.0 have reached q = 1
# Subclones of clone A.1.42.3.2.3.0 have reached q = 1
# Subclones of clone A.1.97.0.0.1.0 have reached q = 1
# Subclones of clone A.1.8.0.0.2.2.0 have reached q = 1
# Subclones of clone A.1.8.0.0.3.3.0 have reached q = 1
# Subclones of clone A.1.8.0.0.3.3.1 have reached q = 1
# Subclones of clone A.1.36.0.0.1.2.0 have reached q = 1
# Subclones of clone A.1.36.0.0.1.2.1 have reached q = 1
# Subclones of clone A.1.36.0.0.1.2.2 have reached q = 1
# Subclones of clone A.1.36.0.0.1.2.3 have reached q = 1
# Subclones of clone A.1.36.0.0.1.2.4 have reached q = 1
# Subclones of clone A.1.36.0.0.1.3.0 have reached q = 1
# Subclones of clone A.1.36.0.0.1.3.1 have reached q = 1
# Subclones of clone A.1.36.0.0.1.3.2 have reached q = 1
# Subclones of clone A.1.36.0.0.1.6.0 have reached q = 1
# Subclones of clone A.1.36.0.0.1.6.1 have reached q = 1
# Subclones of clone A.1.36.0.0.2.0.0 have reached q = 1
# Subclones of clone A.1.36.0.0.2.1.0 have reached q = 1
# Subclones of clone A.1.36.0.0.2.1.1 have reached q = 1
# Subclones of clone A.1.36.0.0.2.1.2 have reached q = 1
# Subclones of clone A.1.36.0.0.4.1.0 have reached q = 1
# Subclones of clone A.1.36.0.0.4.1.1 have reached q = 1
# Subclones of clone A.1.36.0.0.4.1.2 have reached q = 1
# Subclones of clone A.1.36.0.0.4.2.0 have reached q = 1
# Subclones of clone A.1.36.0.0.4.2.1 have reached q = 1
# Subclones of clone A.1.42.9.0.0.0 have reached q = 1
# Subclones of clone A.1.42.9.1.1.0 have reached q = 1
# Subclones of clone A.1.21.0.1.0.0.0 have reached q = 1
# Subclones of clone A.1.63.0.0.2.2.0 have reached q = 1
# Subclones of clone A.1.63.0.0.2.3.0 have reached q = 1
# Subclones of clone A.1.63.0.0.2.3.1 have reached q = 1
# Subclones of clone A.1.63.0.0.2.3.2 have reached q = 1
# Subclones of clone A.1.63.0.0.2.4.0 have reached q = 1
# Subclones of clone A.1.63.0.0.2.4.1 have reached q = 1
# Subclones of clone A.1.4.3.0.1.0.0 have reached q = 1
# Subclones of clone A.1.89.1.1.0.0.0 have reached q = 1
# Subclones of clone A.1.89.1.1.0.1.0 have reached q = 1
# Subclones of clone A.1.89.1.1.0.1.1 have reached q = 1
# Subclones of clone A.1.89.1.1.0.2.0 have reached q = 1
# Subclones of clone A.1.141.0.0.0.0.0 have reached q = 1
# Subclones of clone A.1.141.0.0.0.0.1 have reached q = 1
# Subclones of clone A.1.289.0.0.0.1.0 have reached q = 1
# Subclones of clone A.1.289.0.0.0.1.1 have reached q = 1
# Subclones of clone A.1.289.0.0.0.1.2 have reached q = 1
# Subclones of clone A.1.289.0.0.0.1.3 have reached q = 1
# Subclones of clone A.1.289.0.0.0.2.0 have reached q = 1
# Subclones of clone A.1.21.38.0.0.0 have reached q = 1
# Subclones of clone A.1.2.0.0.0.0.0 have reached q = 1
# Subclones of clone A.1.6.1.0.0.0.0 have reached q = 1
# Subclones of clone A.1.6.1.0.0.0.1 have reached q = 1
# Subclones of clone A.1.6.1.0.0.1.0 have reached q = 1
# Subclones of clone A.1.6.1.0.0.2.0 have reached q = 1
# Subclones of clone A.1.6.1.0.0.2.1 have reached q = 1
# Subclones of clone A.1.6.1.0.0.2.2 have reached q = 1
# Subclones of clone A.1.6.1.1.0.1.0 have reached q = 1
# Subclones of clone A.1.6.1.1.0.1.1 have reached q = 1
# Subclones of clone A.1.6.1.1.0.3.0 have reached q = 1
# Subclones of clone A.1.6.1.1.0.4.0 have reached q = 1
# Subclones of clone A.1.101.0.0.0.0.0.0 have reached q = 1
# Subclones of clone A.1.101.0.0.0.0.0.1 have reached q = 1
# Subclones of clone A.1.101.0.0.0.0.1.0 have reached q = 1
# Subclones of clone A.1.101.0.0.0.0.1.1 have reached q = 1
# Subclones of clone A.1.101.0.0.0.0.1.2 have reached q = 1
# Subclones of clone A.1.21.0.59.0.0 have reached q = 1
# Subclones of clone A.1.21.0.64.0.0 have reached q = 1
# Subclones of clone A.1.21.0.64.0.1 have reached q = 1
# Subclones of clone A.1.21.0.68.0.0 have reached q = 1
# Subclones of clone A.1.21.0.88.0.0 have reached q = 1
# Subclones of clone A.1.21.0.93.0.0 have reached q = 1
# Subclones of clone A.1.21.0.93.0.1 have reached q = 1
# Subclones of clone A.1.21.0.95.0.0 have reached q = 1
# Subclones of clone A.1.21.0.121.0.0 have reached q = 1
# Subclones of clone A.1.21.0.139.0.0 have reached q = 1
# Subclones of clone A.1.21.0.141.0.0 have reached q = 1
# Subclones of clone A.1.21.0.146.0.0 have reached q = 1
# Subclones of clone A.1.21.0.146.0.1 have reached q = 1
# Subclones of clone A.1.21.0.149.0.0 have reached q = 1
# Subclones of clone A.1.21.0.149.1.0 have reached q = 1
# Subclones of clone A.1.21.0.151.0.0 have reached q = 1
# Subclones of clone A.1.21.0.152.0.0 have reached q = 1
# Subclones of clone A.1.21.0.153.0.0 have reached q = 1
# Subclones of clone A.1.63.0.26.0.0 have reached q = 1
# Subclones of clone A.1.63.0.26.0.1 have reached q = 1
# Subclones of clone A.1.63.0.37.0.0 have reached q = 1
# Subclones of clone A.1.63.0.37.0.1 have reached q = 1
# Subclones of clone A.1.101.0.24.0.0 have reached q = 1
# Subclones of clone A.1.6.1.13.0.0 have reached q = 1
# Subclones of clone A.1.6.1.13.0.1 have reached q = 1
# Subclones of clone A.1.6.1.20.0.0 have reached q = 1
# Subclones of clone A.1.6.1.20.0.1 have reached q = 1
# Subclones of clone A.1.6.1.28.0.0 have reached q = 1
# Subclones of clone A.1.6.1.28.0.1 have reached q = 1
# Subclones of clone A.1.6.1.28.0.2 have reached q = 1
# Subclones of clone A.1.11.0.9.0.0 have reached q = 1
# Subclones of clone A.1.11.0.10.0.0 have reached q = 1
# Subclones of clone A.1.11.0.10.0.1 have reached q = 1
# Subclones of clone A.1.11.0.10.0.2 have reached q = 1
# Subclones of clone A.1.36.0.14.0.0 have reached q = 1
# Subclones of clone A.1.36.0.14.0.1 have reached q = 1
# Subclones of clone A.1.36.0.15.0.0 have reached q = 1
# Subclones of clone A.1.36.0.15.0.1 have reached q = 1
# Subclones of clone A.1.89.1.20.0.0 have reached q = 1
# Subclones of clone A.1.21.0.0.1.0.0 have reached q = 1
# Subclones of clone A.1.0.2.2.0.0 have reached q = 1
# Subclones of clone A.1.0.3.1.0.0 have reached q = 1
# Subclones of clone A.1.0.3.1.1.0 have reached q = 1
# Subclones of clone A.1.1.8.4.0.0 have reached q = 1
# Subclones of clone A.1.4.24.0.0.0 have reached q = 1
# Subclones of clone A.1.89.4.2.0.0 have reached q = 1
# Subclones of clone A.1.89.4.2.0.1 have reached q = 1
# Subclones of clone A.1.8.0.0.6.0.0 have reached q = 1
# Subclones of clone A.1.8.0.0.6.0.1 have reached q = 1
# Subclones of clone A.1.8.0.0.6.0.2 have reached q = 1
# Subclones of clone A.1.101.0.0.3.0.0 have reached q = 1
# Subclones of clone A.1.36.0.0.12.0.0 have reached q = 1
# Subclones of clone A.1.21.16.2.0.0 have reached q = 1
# Subclones of clone A.1.21.16.3.0.0 have reached q = 1
# Subclones of clone A.1.26.2.0.0.0 have reached q = 1
# Subclones of clone A.1.26.2.0.1.0 have reached q = 1
# Subclones of clone A.1.45.0.0.0.0 have reached q = 1
# Subclones of clone A.1.95.1.0.0.0 have reached q = 1
# Subclones of clone A.1.21.0.1.1.0.0 have reached q = 1
# Subclones of clone A.1.89.0.0.3.0.0 have reached q = 1
# Subclones of clone A.1.89.0.0.3.0.1 have reached q = 1
# Subclones of clone A.1.89.0.0.3.0.2 have reached q = 1
# Subclones of clone A.1.89.0.0.3.1.0 have reached q = 1
# Subclones of clone A.1.89.0.0.3.1.1 have reached q = 1
# Subclones of clone A.1.89.0.0.3.1.2 have reached q = 1
# Subclones of clone A.1.89.0.0.3.2.0 have reached q = 1
# Subclones of clone A.1.89.0.0.3.2.1 have reached q = 1
# Subclones of clone A.1.89.0.0.3.2.2 have reached q = 1
# Subclones of clone A.1.89.0.0.3.2.3 have reached q = 1
# Subclones of clone A.1.89.0.1.1.0.0 have reached q = 1
# Subclones of clone A.1.89.0.1.1.0.1 have reached q = 1
# Subclones of clone A.1.89.0.1.1.0.2 have reached q = 1
# Subclones of clone A.1.89.0.1.1.0.3 have reached q = 1
# Subclones of clone A.1.4.3.0.2.0.0 have reached q = 1
# Subclones of clone A.1.4.3.0.2.0.1 have reached q = 1
# Subclones of clone A.1.4.7.0.0.0.0 have reached q = 1
# Subclones of clone A.1.89.1.0.6.0.0 have reached q = 1
# Subclones of clone A.1.89.1.0.6.0.1 have reached q = 1
# Subclones of clone A.1.89.1.0.6.0.2 have reached q = 1
# Subclones of clone A.1.89.1.1.1.0.0 have reached q = 1
# Subclones of clone A.1.89.1.1.1.0.1 have reached q = 1
# Subclones of clone A.1.89.1.1.2.0.0 have reached q = 1
# Subclones of clone A.1.289.0.0.1.0.0 have reached q = 1
# Subclones of clone A.1.289.0.0.1.0.1 have reached q = 1
# Subclones of clone A.1.289.0.0.1.0.2 have reached q = 1
# Subclones of clone A.1.289.0.0.1.0.3 have reached q = 1
# Subclones of clone A.1.4.95.1.1.0 have reached q = 1
# Subclones of clone A.1.21.30.1.0.0 have reached q = 1
# Subclones of clone A.1.21.30.1.0.1 have reached q = 1
# ...
# Subclones of clone A.1.12.0.0.0.0.0.0.1.1 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.0.0.1.2 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.0.0.1.3 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.0.0.1.4 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.0.0.1.5 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.0.0.1.6 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.0.0.0 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.0.0.1 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.0.1.0 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.0.1.1 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.0.1.2 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.1.0.0 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.1.0.1 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.1.0.2 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.1.0.3 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.1.0.4 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.1.0.5 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.1.1.0 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.1.1.1 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.1.1.2 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.1.1.3 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.1.1.4 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.1.2.0 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.1.2.1 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.1.2.2 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.1.2.3 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.1.2.4 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.1.3.0 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.1.3.1 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.1.3.2 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.1.3.3 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.1.3.4 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.1.3.5 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.2.1.0 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.2.1.1 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.2.1.2 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.2.1.3 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.2.2.0 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.2.2.1 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.2.2.2 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.2.2.3 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.2.3.0 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.2.3.1 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.2.3.2 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.2.3.3 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.2.3.4 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.2.4.0 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.2.4.1 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.3.0.0 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.3.0.1 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.3.1.0 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.3.1.1 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.3.1.2 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.3.1.3 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.3.2.0 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.3.2.1 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.3.2.2 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.3.2.3 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.3.3.0 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.3.3.1 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.3.3.2 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.3.3.3 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.3.3.4 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.3.3.5 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.3.4.0 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.3.4.1 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.3.4.2 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.4.0.0 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.4.0.1 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.4.0.2 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.4.0.3 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.4.0.4 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.4.0.5 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.4.0.6 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.4.0.7 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.4.0.8 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.4.1.0 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.4.1.1 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.4.1.2 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.4.1.3 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.4.1.4 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.4.1.5 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.4.1.6 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.4.2.0 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.4.2.1 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.4.2.2 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.4.2.3 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.5.0.0 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.5.1.0 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.5.1.1 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.5.1.2 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.5.2.0 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.5.2.1 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.5.2.2 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.5.2.3 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.5.2.4 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.5.3.0 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.5.3.1 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.5.3.2 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.1.5.3.3 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.2.0.0.0 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.2.0.0.1 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.2.0.0.2 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.2.0.0.3 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.2.0.0.4 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.2.0.0.5 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.2.0.1.0 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.2.0.1.1 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.2.0.1.2 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.2.0.1.3 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.2.0.1.4 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.2.1.0.0 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.2.1.0.1 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.2.1.0.2 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.2.1.1.0 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.2.1.1.1 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.2.1.1.2 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.2.1.1.3 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.2.1.2.0 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.2.1.2.1 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.2.1.2.2 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.2.1.3.0 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.2.1.3.1 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.2.1.3.2 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.2.1.3.3 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.2.1.3.4 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.2.1.3.5 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.2.2.0.0 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.2.2.0.1 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.2.2.1.0 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.2.2.1.1 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.2.2.1.2 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.2.2.1.3 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.2.2.1.4 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.2.2.1.5 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.2.2.1.6 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.2.2.2.0 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.2.2.2.1 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.2.2.2.2 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.2.2.2.3 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.2.2.2.4 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.2.2.2.5 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.2.2.3.0 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.2.2.3.1 have reached q = 1
# Subclones of clone A.1.12.0.0.0.0.2.2.3.2 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.0.0.0.0 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.0.0.0.1 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.0.0.0.2 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.0.0.1.0 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.0.0.2.0 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.0.0.2.1 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.0.1.0.0 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.0.1.0.1 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.0.1.1.0 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.0.1.1.1 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.0.1.1.2 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.0.1.2.0 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.0.1.2.1 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.0.1.2.2 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.0.1.2.3 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.0.1.3.0 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.0.1.3.1 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.0.2.0.0 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.0.2.0.1 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.0.2.0.2 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.0.2.1.0 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.0.2.1.1 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.0.2.1.2 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.0.3.0.0 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.0.3.0.1 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.0.3.0.2 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.0.3.0.3 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.0.3.0.4 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.0.3.1.0 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.0.3.1.1 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.0.3.1.2 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.0.3.1.3 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.0.3.2.0 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.0.3.2.1 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.0.4.0.0 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.0.4.0.1 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.0.4.0.2 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.0.4.0.3 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.0.4.0.4 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.0.4.0.5 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.0.4.0.6 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.0.4.1.0 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.0.5.0.0 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.0.5.0.1 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.0.5.1.0 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.0.6.0.0 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.0.6.0.1 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.0.6.1.0 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.0.6.1.1 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.0.6.2.0 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.0.6.3.0 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.0.7.0.0 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.0.7.0.1 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.0.7.0.2 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.0.7.0.3 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.0.7.0.4 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.0.8.0.0 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.0.8.0.1 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.2.0.0.0 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.2.0.0.1 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.2.0.1.0 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.2.0.1.1 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.2.0.1.2 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.2.0.1.3 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.2.0.2.0 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.2.0.2.1 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.2.0.3.0 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.2.0.3.1 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.2.0.4.0 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.2.0.4.1 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.2.0.4.2 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.2.0.4.3 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.2.0.4.4 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.3.0.0.0 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.3.0.1.0 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.3.1.0.0 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.3.3.0.0 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.3.3.0.1 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.3.3.0.2 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.3.3.0.3 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.3.3.1.0 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.3.3.1.1 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.3.3.2.0 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.3.3.2.1 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.3.4.0.0 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.3.4.0.1 have reached q = 1
# Subclones of clone A.1.8.0.0.1.0.0.3.4.0.2 have reached q = 1
# Subclones of clone A.1.63.0.0.0.0.0.0.0.0.0 have reached q = 1
# Subclones of clone A.1.63.0.0.0.0.1.0.0.0.0 have reached q = 1
# Subclones of clone A.1.63.0.0.0.0.1.0.0.0.1 have reached q = 1
# Subclones of clone A.1.63.0.0.0.0.1.0.0.1.0 have reached q = 1
# Subclones of clone A.1.63.0.0.0.0.1.0.2.0.0 have reached q = 1
# Subclones of clone A.1.63.0.0.0.0.1.0.2.0.1 have reached q = 1
# Subclones of clone A.1.63.0.0.0.0.1.0.2.0.2 have reached q = 1
# Subclones of clone A.1.63.0.0.0.0.1.0.2.0.3 have reached q = 1
# Subclones of clone A.1.63.0.0.0.0.1.0.2.2.0 have reached q = 1
# Subclones of clone A.1.63.0.0.0.0.1.0.2.3.0 have reached q = 1
# Subclones of clone A.1.63.0.0.0.0.2.0.0.0.0 have reached q = 1
# Subclones of clone A.1.63.0.0.0.0.2.0.0.0.1 have reached q = 1
# Subclones of clone A.1.63.0.0.0.0.2.0.0.0.2 have reached q = 1
# Subclones of clone A.1.63.0.0.0.0.2.0.0.0.3 have reached q = 1
# Subclones of clone A.1.63.0.0.0.0.2.0.0.1.0 have reached q = 1
# Subclones of clone A.1.63.0.0.0.0.2.0.0.2.0 have reached q = 1
# Subclones of clone A.1.63.0.0.0.0.2.0.0.2.1 have reached q = 1
# Subclones of clone A.1.63.0.0.0.0.2.0.0.2.2 have reached q = 1
# Subclones of clone A.1.63.0.0.0.0.2.0.0.3.0 have reached q = 1
# Subclones of clone A.1.63.0.0.0.0.2.0.0.3.1 have reached q = 1
# Subclones of clone A.1.63.0.0.0.0.2.0.0.4.0 have reached q = 1
# Subclones of clone A.1.63.0.0.0.0.2.0.0.4.1 have reached q = 1
# Subclones of clone A.1.63.0.0.0.0.2.0.0.4.2 have reached q = 1
# Subclones of clone A.1.63.0.0.0.0.2.0.0.5.0 have reached q = 1
# Subclones of clone A.1.63.0.0.0.0.2.0.1.0.0 have reached q = 1
# Total population size: 116402657
# Generations: 35
#
# Start clone size: 1775046
# Number of subclones: 964706
# CPU times: user 51 s, sys: 12.8 s, total: 1min 3s
# Wall time: 1min 1s

# %% [markdown]
# ## SAMPLED DATA

# %%
sample_size = 10**6
detection_limit = 100

# %%
# %%time
large_N_data = final_data(large_N)
large_S_data = final_data(large_S)

large_N_data = sample(large_N_data, sample_size, detection_limit)
large_S_data = sample(large_S_data, sample_size, detection_limit)
# Out:
# CPU times: user 33.1 s, sys: 538 ms, total: 33.6 s
# Wall time: 34.2 s

# %%
large_N_data.describe()
# Out:
#           Birthday            q    Final size   Family size  Allele frequency  \
# count  1062.000000  1062.000000  1.062000e+03  1.062000e+03      1.062000e+03
# mean     25.148776     0.003117  1.090362e+05  1.103995e+05      9.484272e-04
# std       2.335743     0.000838  3.528026e+06  3.571891e+06      3.068565e-02
# min       0.000000     0.001000  0.000000e+00  1.000000e+02      8.590869e-07
# 25%      24.000000     0.003000  1.430000e+02  1.450000e+02      1.245676e-06
# 50%      25.000000     0.003000  2.320000e+02  2.355000e+02      2.023150e-06
# 75%      27.000000     0.003000  4.765000e+02  4.915000e+02      4.222412e-06
# max      29.000000     0.009000  1.149731e+08  1.164027e+08      1.000000e+00
#
#          Mutations       Children  Weight   sampled_size  sampled_fam_size  \
# count  1062.000000    1062.000000  1062.0    1062.000000       1062.000000
# mean      1.018832     157.541431     1.0     941.619586        948.620527
# std       0.142759    5023.566660     0.0   30459.308251      30685.645284
# min       0.000000       0.000000     1.0       0.000000          1.000000
# 25%       1.000000       0.000000     1.0       1.000000          1.000000
# 50%       1.000000       1.000000     1.0       2.000000          2.000000
# 75%       1.000000       2.000000     1.0       4.000000          4.000000
# max       2.000000  163711.000000     1.0  992624.000000    1000000.000000
#
#         sampled_AF
# count  1062.000000
# mean      0.000949
# std       0.030686
# min       0.000001
# 25%       0.000001
# 50%       0.000002
# 75%       0.000004
# max       1.000000

# %%
large_S_data.describe()
# Out:
#           Birthday            q    Final size   Family size  Allele frequency  \
# count  5735.000000  5735.000000  5.735000e+03  5.735000e+03      5.735000e+03
# mean     28.234699     0.026960  1.980391e+04  4.681247e+04      4.021598e-04
# std       2.166351     0.039221  1.064943e+06  2.156649e+06      1.852749e-02
# min       0.000000     0.001000  0.000000e+00  1.000000e+02      8.590869e-07
# 25%      27.000000     0.009000  1.420000e+02  1.590000e+02      1.365948e-06
# 50%      29.000000     0.009000  2.480000e+02  2.790000e+02      2.396853e-06
# 75%      30.000000     0.027000  5.765000e+02  6.680000e+02      5.738701e-06
# max      32.000000     0.729000  8.022005e+07  1.164027e+08      1.000000e+00
#
#          Mutations       Children       Weight   sampled_size  \
# count  5735.000000    5735.000000  5735.000000    5735.000000
# mean      2.576112     143.201569     4.368500     174.367916
# std       0.778205    4891.869315     1.679126    9344.884512
# min       0.000000       0.000000     0.861528       0.000000
# 25%       2.000000       3.000000     3.126375       1.000000
# 50%       2.000000       6.000000     3.997283       2.000000
# 75%       3.000000      16.000000     5.389576       6.000000
# max       6.000000  357641.000000    13.413686  703873.000000
#
#        sampled_fam_size   sampled_AF
# count       5735.000000  5735.000000
# mean         400.636617     0.000401
# std        18523.647488     0.018524
# min            1.000000     0.000001
# 25%            1.000000     0.000001
# 50%            3.000000     0.000003
# 75%            6.000000     0.000006
# max      1000000.000000     1.000000

# %% [markdown]
# ## Allele frequency spectrum for Neutral Population

# %%
large_N_af = large_N_data["sampled_AF"]
sns.distplot(large_N_af.iloc[1:], kde=False, norm_hist=False, bins=100, color='b')
plt.ylabel('Number of mutations');
plt.xlabel('Allele frequency');
plt.yscale('log');
plt.savefig("./Figures/Large-MUTATOR-Neutral_vs_Selection-SAMPLED/SAMPLED-large_N-AF_spec.png", bbox_inches='tight');
plt.show()

# %% [markdown]
# ## Allele frequency spectrum for Population with Selection

# %%
large_S_af = large_S_data["sampled_AF"]
sns.distplot(large_S_af.iloc[1:], kde=False, norm_hist=False, bins=100, color='r')
plt.ylabel('Number of mutations');
plt.xlabel('Allele frequency');
plt.yscale('log');
plt.savefig("./Figures/Large-MUTATOR-Neutral_vs_Selection-SAMPLED/SAMPLED-large_S-AF_spec.png", bbox_inches='tight');
plt.show()

# %% [markdown]
# ## Cumulative number of mutations in function of inverse allele frequency

# %%
fit_large_N_af_r_value = fit_cumulative_mutations(large_N_data, sampled=True, plot=True)
print("\nR^2 =", fit_large_N_af_r_value)
plt.title("Cumulative number of mutations for large_N population");
plt.savefig("./Figures/Large-MUTATOR-Neutral_vs_Selection-SAMPLED/SAMPLED-large_N-Cum_num_M.png", bbox_inches='tight');
plt.show()

fit_large_S_af_r_value = fit_cumulative_mutations(large_S_data, sampled=True, plot=True)
print("\nR^2 =", fit_large_S_af_r_value)
plt.title("Cumulative number of mutations for large_S population");
plt.savefig("./Figures/Large-MUTATOR-Neutral_vs_Selection-SAMPLED/SAMPLED-large_S-Cum_num_M.png", bbox_inches='tight');
plt.show()
# Out:
# R^2 = 0.979988639914847
# R^2 = 0.9780610663591885

# %% [markdown]
# ## Heterogeneity

# %%
large_N_H = heterogeneity(large_N_data, sampled=True)
large_S_H = heterogeneity(large_S_data, sampled=True)
print(large_N_H, large_S_H)
sns.barplot(x=[0, 1], y=[large_N_H, large_S_H]);
plt.xticks([0,1], ["Neutral", "Selection = 0.3"]);
plt.ylabel("H");
plt.title("Comparison of Heterogeneity");
plt.savefig("./Figures/Large-MUTATOR-Neutral_vs_Selection-SAMPLED/SAMPLED-Neutral_vs_Sel-Heterogeneity.png", bbox_inches='tight')
plt.show()
# Out:
# 0.9543226654407261 0.48334988980211846

# %% [markdown]
# ## Distribution of number of mutations

# %%
large_N_num_mut_df = num_mutations_distribution(large_N_data, sampled=True, det_lim=detection_limit)
large_N_avg_num_mut = avg_num_mutations(large_N_num_mut_df)
large_N_num_mut_df.columns = ["Neutral, mean = %s" %(round(large_N_avg_num_mut, 3))]
#large_N_num_mut_df.plot(kind='bar', logy=True, legend=True, rot=0, color='b', alpha=0.6);

large_S_num_mut_df = num_mutations_distribution(large_S_data, sampled=True, det_lim=detection_limit)
large_S_avg_num_mut = avg_num_mutations(large_S_num_mut_df)
large_S_num_mut_df.columns = ["Selection = %s, mean = %s" %(sel, round(large_S_avg_num_mut, 3))]
#large_S_num_mut_df.plot(kind='bar', logy=True, legend=True, rot=0, color='r', alpha=0.6);

combo = large_N_num_mut_df.join(large_S_num_mut_df, how='right')
print(combo)
combo.plot(kind='bar', logy=True, legend=True, rot=0, color=['b', 'r'], alpha=0.6);

plt.ylabel("Cell count");
plt.xlabel("Number of mutations");
plt.legend(frameon=True, fancybox=True, shadow=True);
plt.savefig("./Figures/Large-MUTATOR-Neutral_vs_Selection-SAMPLED/SAMPLED-Neutral_vs_Sel-Num_mut.png", bbox_inches='tight')
plt.show()
# Out:
#              Neutral, mean = 1.005  Selection = 0.3, mean = 1.317
# # mutations
# 1                           7441.0                         707513
# 2                             40.0                         243743
# 3                              NaN                          29842
# 4                              NaN                           2727
# 5                              NaN                            156
